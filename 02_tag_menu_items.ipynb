# %%
import os
from pathlib import Path
import pandas as pd
from utils.html_parser import extract_dishes_from_html
from utils.diet_rules import apply_heuristics
from utils.diet_agent import classify_dish

"""
This script processes raw HTML data of dishes, applies both heuristic
and LLM-based classification logic, compares both results, and finalizes
a dataset with inferred dietary tags for further usage.

Key idea:
- Heuristic rules are fast and reliable for obvious patterns (e.g., low kcal).
- LLM inference is preferred when domain judgment is required (e.g., is_gourmet).
- Final flags are taken from the LLM agent (`df_agent`), assuming deeper reasoning.
  However, manual overrides or forced heuristic rules can be applied later if needed.
"""

# 1. Parse HTML input into structured DataFrame
df = extract_dishes_from_html(Path("data/raw.html"))
print(f"✅ Parsed {len(df)} dishes")

# 2. Apply rule-based heuristics to extract simple, logic-driven tags
df_heur = df.copy()
heuristics_df = df_heur.apply(apply_heuristics, axis=1).tolist()
df_heur = df_heur.join(pd.DataFrame(heuristics_df))
print("✅ Heuristics applied")

# 3. Use LLM-based agent to classify the dishes, considering full context
records = df_heur.to_dict(orient="records")
df_agent = pd.DataFrame([classify_dish(r).model_dump() for r in records])
print("✅ Agent classification done")

# 4. Compare Heuristic vs LLM output to spot conflicts or review borderline cases

# Reset indexes to align both DataFrames for row-wise comparison
df_heur = df_heur.reset_index(drop=True)
df_agent = df_agent.reset_index(drop=True)

# Identify which flags will be compared (all boolean classification tags)
flag_cols = [c for c in df_heur.columns if c.startswith((
    "is_", "bajo_en_calorias", "es_postre", "de_cuchara",
    "alto_proteina", "sin_lactosa", "is_gourmet", "para_diabeticos", "sin_gluten", "congelar"
))]

# Combine both outputs for side-by-side review
df_cmp = pd.concat([df_heur, df_agent.add_suffix("_agent")], axis=1)

# Identify rows where any flag differs between heuristic and agent
mask_diff = pd.DataFrame({
    col: df_cmp[col] != df_cmp[col + "_agent"] 
    for col in flag_cols
})
rows_diff = df_cmp[mask_diff.any(axis=1)]

print(f"🔍 Found {len(rows_diff)} mismatches between heuristic and agent")

# Print details of each conflict to aid human-in-the-loop inspection
for _, r in rows_diff.iterrows():
    print("-" * 50)
    print(f"🍽️ Dish: {r['nombre_plato']}")
    print(f"Ingredients: {r['ingredientes']}")
    print(f"Kcal: {r['kcal']}")
    print("Differences found:")
    for col in flag_cols:
        if r[col] != r[col + "_agent"]:
            print(f" • {col}: heuristic={r[col]}, agent={r[col + '_agent']}")
    print("-" * 50 + "\n")

# 5. Finalize output DataFrame using LLM results

"""
At this point, we build the final dataset by combining the original dish data
with the flags inferred by the LLM. For this version, we **trust the LLM agent's
inference** as the most comprehensive classification source, given its broader context awareness.

However, if necessary, one could force specific tags using:
  - a rule-based override for certain fields
  - a manual correction for certain dishes

This allows full flexibility between automation and human review.
"""

df_final_official = pd.concat([df, df_agent], axis=1)
print("✅ df_final_official is ready:")
display(df_final_official.head())
# Out:
# ✅ Parsed 241 dishes
# ✅ Heuristics applied
# ✅ Agent classification done
# 🔍 Found 165 mismatches between heuristic and agent
# --------------------------------------------------
# 🍽️ Nombre: Ají de Pollo
# Ingredientes: Pollo, 26.38%, Agua, Cebolla, Huevo (HUEVO), leche (LÁCTEOS), Arroz, Pan (GLUTEN), Almendra (FRUTOS DE CÁSCARA), Queso (LÁCTEOS), Aceite de Oliva, Ajo, Aceitunas, Ají Amarillo 0.73%, Mantequilla (LÁCTEOS), Sal,Pollo, Cúrcuma, Comino, Pimienta Negra y Laurel
# Kcal: 146.0
# Diferencias detectadas:
#  • sin_gluten: heurístico=True, agente=False
# --------------------------------------------------
#
# --------------------------------------------------
# 🍽️ Nombre:
#  • sin_gluten: heurístico=False, agente=True
# --------------------------------------------------
#
# --------------------------------------------------
# 🍽️ Nombre: Calabacines Rellenos de Carne
# Ingredientes: Calabacines 45.70%, Queso sin Lactosa (LÁCTEOS), leche  Sin Lactosa(LÁCTEOS), Agua, Cerdo 6.58%, Cebolla, Tomate, Aceite de Oliva, Harina de maiz, Vino, Patatas, Pimiento, Zanahoria, Sal, Ajo, Nuez Moscada y Pimienta
# Kcal: 96.0
# Diferencias detectadas:
#  • bajo_en_calorias: heurístico=False, agente=True
#  • sin_gluten: heurístico=False, agente=True
# --------------------------------------------------
#
# --------------------------------------------------
# 🍽️ Nombre: Caldereta de Venado
# Ingredientes: Venado 37%, Pimiento, Cebolla, Vino, Zanahoria, Tomates, Aceite de Oliva, Ajo, Sal, Tomillo, Romero y Pimienta
# Kcal: 98.8
# Diferencias detectadas:
#  • is_vegano: heurístico=True, agente=False
#  • is_vegetariano: heurístico=True, agente=False
#  • is_keto: heurístico=False, agente=True
#  • bajo_en_calorias: heurístico=False, agente=True
# --------------------------------------------------
#
# --------------------------------------------------
# 🍽️ Nombre: Coliflor al Ajillo y Pimentón
# Ingredientes: Coliflor 92.17%, Ajo 3.68%, Aceite de Oliva, Vinagre, Sal y Pimentón Dulce 0.69%.
# Kcal: 65.5
# Diferencias detectadas:
#  • es_postre: heurístico=True, agente=False
# --------------------------------------------------
#
# --------------------------------------------------
# 🍽️ Nombre: Coliflor con Bechamel y Queso
# Ingredientes: Coliflor 44.48%, leche  Sin Lactosa(LÁCTEOS), Agua, Huevo (HUEVO), Aceite de Oliva, Queso (LÁCTEOS), Harina de maiz, Sal, Nuez Moscada
# Kcal: 56.3
# Diferencias detectadas:
#  • sin_gluten: heurístico=False, agente=True
# --------------------------------------------------
#
# --------------------------------------------------
# 🍽️ Nombre: Crema de Calabacín con Quesitos
# Ingredientes: Calabacín 38.59%, Cebolla, Agua, Queso Sin Lactosa 6.10% (LÁCTEOS), Nata (LÁCTEOS) y Sal.
# Kcal: 55.3
# Diferencias detectadas:
#  • es_postre: heurístico=True, agente=False
# --------------------------------------------------
#
# --------------------------------------------------
# 🍽️ Nombre: Crema de Calabaza
# Ingredientes: Agua, Calabaza 28.83%, Patata, Cebolla, Zanahoria, Nata (LÁCTEOS), Aceite de Oliva, Ajo, Sal y Caldo de Verduras
# Kcal: 39.6
# Diferencias detectadas:
#  • es_postre: heurístico=True, agente=False
# --------------------------------------------------
#
# --------------------------------------------------
# 🍽️ Nombre: Crema de Espinacas
# Ingredientes: Espinacas 29.34%, Agua, Patata, Cebolla, Nata (LÁCTEOS), Queso (LÁCTEOS), Ajo y Sal.
# Kcal: 47.6
# Diferencias detectadas:
#  • es_postre: heurístico=True, agente=False
# --------------------------------------------------
#
# --------------------------------------------------
# 🍽️ Nombre: Curry Amarillo de Salmón y Brócoli
# Ingredientes: Salmón 27.75% (PESCADO), Brócoli 25.10%, leche de Coco, Zanahoria, Calabacín, Berenjenas, Mango, Cebolla, Pimiento, Tomates, Cacahuetes (FRUTOS DE CÁSCARA), Curry Amarillo 1.29%, Ajo, Caldo de Verduras y Sal
# Kcal: 109.0
# Diferencias detectadas:
#  • sin_lactosa: heurístico=False, agente=True
#  • congelar: heurístico=False, agente=True
# --------------------------------------------------
#
# --------------------------------------------------
# 🍽️ Nombre: Lasaña de Verduras
# Ingredientes: Calabacín 13.45%, Cebolla 11.21%, leche  Sin Lactosa(LÁCTEOS), Espinacas 8.97%, Agua, Zanahoria 6.73%, Sémola de trigo 6.42% (GLUTEN), Berenjenas 5.61%, Nata (LÁCTEOS), Tomates 9.61%, Aceite de Oliva, Pimiento 5.60%, Queso Sin Lactosa (LÁCTEOS), Harina de maiz, Caldo de Verduras, Sal, Nuez Moscada y Pimienta Blanca
# Kcal: 70.5
# Diferencias detectadas:
#  • es_postre: heurístico=True, agente=False
# --------------------------------------------------
#
# --------------------------------------------------
# 🍽️ Nombre: Musaka
# Ingredientes: Berenjenas 57.36%, leche (LÁCTEOS) Sin Lactosa, Agua, Ternera, Cerdo, Tomate, Queso Sin Lactosa (LÁCTEOS), Cebolla, Aceite de Oliva, Harina de maiz, Zanahoria, Bacon, Vino, Sal, Ajo, Caldo de Carne, Nuez Moscada y Orégano
# Kcal: 103.0
# Diferencias detectadas:
#  • is_keto: heurístico=True, agente=False
#  • sin_lactosa: heurístico=False, agente=True
#  • sin_gluten: heurístico=False, agente=True
# --------------------------------------------------
#
# --------------------------------------------------
# 🍽️ Nombre: Pan Keto o Cetogénico (500 gr.)
# Ingredientes: Mix panario [mix de proteínas (proteína de trigo, proteína de soja (SOJA), proteína de lupino), harina de soja (SOJA), semillas de linaza marrón y amarilla, semillas de girasol, harina de soja (SOJA), harina de trigo integral, salvado de trigo, fibra de manzana, semillas de sésamo (SÉSAMO), sal, harina de malta de cebada tostada, emulsionante, regulador de la acidez (diacetato de sodio)], agua, aceite de girasol, levadura, conservante (propionato de calcio), conservante, avena (GLUTEN)
# Kcal: 304.0
# Diferencias detectadas:
#  • congelar: heurístico=True, agente=False
# --------------------------------------------------
#
# --------------------------------------------------
# 🍽️ Nombre: Pastel de Berenjenas y Carne
# Ingredientes: Berenjenas 23.72%, Cerdo, Huevo (HUEVO), Queso Sin Lactosa (LÁCTEOS), Pimiento, Cebolla, Nata(LÁCTEOS), Aceite de Oliva y Sal
# Kcal: 168.0
# Diferencias detectadas:
#  • es_postre: heurístico=True, agente=False
# --------------------------------------------------
#
# --------------------------------------------------
# 🍽️ Nombre: Pavo al Curry y Coliflor
# Ingredientes: Pavo 41.72%, Coliflor 32.10%, Queso (LÁCTEOS), Cebolla, Nata (LÁCTEOS), Tomate, Aceite de Oliva, Curry Amarillo 0.39% y Sal
# Kcal: 90.6
# Diferencias detectadas:
#  • is_vegetariano: heurístico=True, agente=False
#  • is_keto: heurístico=False, agente=True
#  • bajo_en_calorias: heurístico=False, agente=True
#  • es_postre: heurístico=True, agente=False
#  • alto_proteina: heurístico=False, agente=True
# --------------------------------------------------
#
# --------------------------------------------------
# 🍽️ Nombre: Pechuga de Pavo en Salsa de Gambas, Ajos Tiernos y Setas
# Ingredientes: Pavo 47.28%, Setas 11.82%, Ajos, Gambas 11.82% (CRUSTÁCEOS), Cebolla, Vino, Nata (LÁCTEOS), Agua, Aceite de Oliva, Harina de maiz, Pimentón Dulce, Sal y Pimienta Blanca
# Kcal: 122.0
# Diferencias detectadas:
#  • es_postre: heurístico=True, agente=False
#  • sin_gluten: heurístico=False, agente=True
# --------------------------------------------------
#
# --------------------------------------------------
# 🍽️ Nombre: Pimientos Rellenos en Salsa Riojana
# Ingredientes: Pimiento 34.52%, Cerdo, Ternera, Cebolla, Pimiento, Pan (GLUTEN), Huevo (HUEVO), Aceite de Oliva, Salsa Inglesa (Vinagre de Malta, Vinagre de Alcohol, Melaza, Azúcar, Sal, Anchoas (PESCADO), Extracto de Tamarindo, Cebolla, Ajo, Especias y Aromas), Caldo de Carne, Sal, Ajo, Perejil y Comino
# Kcal: 107.0
# Diferencias detectadas:
#  • is_keto: heurístico=True, agente=False
#  • es_postre: heurístico=True, agente=False
#  • sin_gluten: heurístico=True, agente=False
#  • congelar: heurístico=False, agente=True
# --------------------------------------------------
#
# --------------------------------------------------
# 🍽️ Nombre: Pisto
# Ingredientes: Cebolla, Patatas, Tomate, Sal, Aceite de Oliva, Pimiento, Calabacín, Berenjenas y Pimienta Blanca
# Kcal: 89.3
# Diferencias detectadas:
#  • bajo_en_calorias: heurístico=False, agente=True
# --------------------------------------------------
#
# --------------------------------------------------
# 🍽️ Nombre: Pollo a la Carbonara con Champiñones
# Ingredientes: Pollo 50.80%, Champiñones 19.94%, Nata (LÁCTEOS), Cebolla, Queso (LÁCTEOS), Mantequilla (LÁCTEOS), Aceite de Oliva, Ajo, Sal y Pimienta
# Kcal: 98.0
# Diferencias detectadas:
#  • is_keto: heurístico=False, agente=True
#  • bajo_en_calorias: heurístico=False, agente=True
#  • es_postre: heurístico=True, agente=False
# --------------------------------------------------
#
# --------------------------------------------------
# 🍽️ Nombre: Pollo a la Manzanilla con Bechamel
# Ingredientes: Pollo 49.57%, leche Sin Lactosa (LÁCTEOS), Agua, Sal, Aceite de Oliva, Nuez Moscada, Harina de maiz, Setas, Vino, Salsa de soja (SOJA) y Azúcar
# Kcal: 147.0
# Diferencias detectadas:
#  • is_keto: heurístico=True, agente=False
#  • es_postre: heurístico=True, agente=False
#  • sin_gluten: heurístico=False, agente=True
#  • congelar: heurístico=False, agente=True
# --------------------------------------------------
#
# --------------------------------------------------
# 🍽️ Nombre: Pollo al Chilindrón
# Ingredientes: Pollo 44%, Cebolla, Pimiento, Tomate, Jamón, Vino, Aceite de Oliva, Sal, Ajo, Pimentón Dulce, Pimienta Blanca y Perejil
# Kcal: 132.0
# Diferencias detectadas:
#  • es_postre: heurístico=True, agente=False
# --------------------------------------------------
#
# --------------------------------------------------
# 🍽️ Nombre: Pollo al Pesto con Nata
# Ingredientes: Pollo 56.34%, Nata (LÁCTEOS), Espinacas, Albahaca, Piñones, Queso (LÁCTEOS), Aceitunas Negras, Mantequilla, Ajo, Sal y Pimienta
# Kcal: 183.0
# Diferencias detectadas:
#  • es_postre: heurístico=True, agente=False
# --------------------------------------------------
#
# --------------------------------------------------
# 🍽️ Nombre:
0
# Diferencias detectadas:
#  • es_postre: heurístico=True, agente=False
#  • alto_proteina: heurístico=False, agente=True
# --------------------------------------------------
#
# --------------------------------------------------
# 🍽️ Nombre: Callos a la Madrileña con Garbanzos
# Ingredientes: Ternera 43.86%, Garbanzos 18.71%, Agua, Cebolla, Jamón, Chorizo, Pimiento Choricero, Morcilla, Aceite de Oliva, Ajo, Sal, Cayena, Pimienta Negra y Laurel
# Kcal: 150.0
# Diferencias detectadas:
#  • de_cuchara: heurístico=False, agente=True
# --------------------------------------------------
#
# --------------------------------------------------
# 🍽️ Nombre: Cocido Madrileño
# Ingredientes: Agua, Garbanzos 30.62%, Patatas, Cerdo, Pollo, Col, Zanahoria, Cebolla, Chorizo, Morcilla, Aceite de Oliva, Caldo de Carne, Sal y Hueso de Jamón
# Kcal: 101.0
# Diferencias detectadas:
#  • de_cuchara: heurístico=False, agente=True
# --------------------------------------------------
#
# --------------------------------------------------
# 🍽️ Nombre: Espinacas con Garbanzos
# Ingredientes: Espinacas 62.20%, Garbanzos, 31.10%, Aceite de Oliva, Pan (GLUTEN), Ajo, Pimentón, Sal y Comino
# Kcal: 78.0
# Diferencias detectadas:
#  • sin_gluten: heurístico=True, agente=False
#  • congelar: heurístico=True, agente=False
# --------------------------------------------------
#
# --------------------------------------------------
# 🍽️ Nombre: Fabada Asturiana Casera
# Ingredientes: Agua, Fabes 12.84%, Cerdo, Lacon, Chorizo Asturiano, Morcilla Asturiana, Aceite de Oliva y Pimentón Dulce
# Kcal: 156.0
# Diferencias detectadas:
#  • es_postre: heurístico=True, agente=False
#  • de_cuchara: heurístico=False, agente=True
# --------------------------------------------------
#
# --------------------------------------------------
# 🍽️ Nombre: Garbanzos con Langostinos y Chorizo
# Ingredientes: Garbanzos 42.18%, Langostino (CRUSTÁCEOS) 20.46%, Agua, Chorizo 5.30%, Cebolla, Pimiento, Tomate, Vino, Aceite de Oliva, Sal, Harina de maiz, Caldo de Carne, Ajo y Perejil
# Kcal: 152.0
# Diferencias detectadas:
#  • de_cuchara: heurístico=False, agente=True
#  • congelar: heurístico=True, agente=False
# --------------------------------------------------
#
# --------------------------------------------------
# 🍽️ Nombre: Garbanzos con Verduras
# Ingredientes: Garbanzos 20.50, Pimiento 13.45%, Cebolla, 11.53%, Zanahoria 9.81%, Agua, Tomate 9.06%, Calabaza 7.69%, Judías Verdes 6.41%, Calabacín 5.68%, Patata 2.56%, Aceite de Oliva, Ajo, Caldo de Verduras y Pimentón Dulce
# Kcal: 92.6
# Diferencias detectadas:
#  • bajo_en_calorias: heurístico=False, agente=True
#  • es_postre: heurístico=True, agente=False
#  • de_cuchara: heurístico=False, agente=True
# --------------------------------------------------
#
# --------------------------------------------------
# 🍽️ Nombre: Judías Blancas con Chorizo
# Ingredientes: Alubias Blancas 36.26%, Agua, Patata, Cebolla, Chorizo 7.93%, Pimiento, Zanahoria, Aceite de Oliva, Ajo, Sal y Pimentón Dulce
# Kcal: 91.1
# Diferencias detectadas:
#  • is_vegano: heurístico=True, agente=False
#  • is_vegetariano: heurístico=True, agente=False
#  • bajo_en_calorias: heurístico=False, agente=True
#  • es_postre: heurístico=True, agente=False
#  • de_cuchara: heurístico=False, agente=True
# --------------------------------------------------
#
# --------------------------------------------------
# 🍽️ Nombre: Judías Pintas con Verduritas y Jamón Serrano
# Ingredientes: Judías Pintas 39.96%, Agua, Jamón 12.65%, Zanahoria 5.20%, Cebolla 5.05%, Tomates 3.29, Pimiento 5,5%, Aceite de Oliva, Ajo, Pimentón dulce, Sal, Pimienta Blanca y Laurel
# Kcal: 99.6
# Diferencias detectadas:
#  • bajo_en_calorias: heurístico=False, agente=True
#  • es_postre: heurístico=True, agente=False
#  • de_cuchara: heurístico=False, agente=True
# --------------------------------------------------
#
# --------------------------------------------------
# 🍽️ Nombre: Lentejas con Verduras
# Ingredientes: Agua, Lentejas 13.61%, Patata 10.20%, Zanahoria 7.99%, Cebolla 6.80%, Calabaza 5.44%, Tomate 4.08%, Pimiento 6.80%, Puerro 2.72%, Aceite de Oliva, Caldo de Verduras, Ajo y Pimentón Dulce
# Kcal: 73.7
# Diferencias detectadas:
#  • es_postre: heurístico=True, agente=False
#  • de_cuchara: heurístico=False, agente=True
# --------------------------------------------------
#
# --------------------------------------------------
# 🍽️ Nombre: Lentejas Riojanas
# Ingredientes: Agua, Lentejas 18.25%, Patata, Chorizo 10.48%, Zanahoria, Cebolla, Pimiento, Aceite de Oliva, Sal, Pimentón Dulce y Laurel
# Kcal: 94.4
# Diferencias detectadas:
#  • is_vegano: heurístico=True, agente=False
#  • is_vegetariano: heurístico=True, agente=False
#  • bajo_en_calorias: heurístico=False, agente=True
#  • es_postre: heurístico=True, agente=False
#  • de_cuchara: heurístico=False, agente=True
#  • sin_gluten: heurístico=True, agente=False
# --------------------------------------------------
#
# --------------------------------------------------
# 🍽️ Nombre:
0
# Diferencias detectadas:
#  • es_postre: heurístico=True, agente=False
# --------------------------------------------------
#
# --------------------------------------------------
# 🍽️ Nombre: Lasaña de Atún
# Ingredientes: Sémola de trigo 21.54% (GLUTEN), leche sin lactosa (LÁCTEOS), Agua, Atún (PESCADO) 9.77%, Tomate, Huevo (HUEVO), Cebolla, Tomate, Pimiento, Aceite de Oliva, Queso Sin Lactosa (LÁCTEOS), Harina de maiz, Patata, Sal y Nuez Moscada
# Kcal: 153.0
# Diferencias detectadas:
#  • sin_lactosa: heurístico=False, agente=True
# --------------------------------------------------
#
# --------------------------------------------------
# 🍽️ Nombre: Lasaña de Jamón de York y Queso
# Ingredientes: Jamón York 25.81%, Queso Sin Lactosa 17.77% (LÁCTEOS), leche Sin Lactosa (LÁCTEOS), Agua, Tomate, Sémola de trigo 7.29% (GLUTEN), Aceite de Oliva, Harina de maiz, Sal, Ajo, Orégano y Nuez Moscada
# Kcal: 210.0
# Diferencias detectadas:
#  • sin_lactosa: heurístico=False, agente=True
# --------------------------------------------------
#
# --------------------------------------------------
# 🍽️ Nombre: Macarrones con Atún
# Ingredientes: Tomate, Sémola de trigo 18.09% (GLUTEN), Aceite de Oliva, Atún (PESCADO) 12.06%, Tomate, Cebolla, Pimiento, Sal, Ajo, Orégano, Albahaca y Pimienta
# Kcal: 202.0
# Diferencias detectadas:
#  • congelar: heurístico=True, agente=False
# --------------------------------------------------
#
# --------------------------------------------------
# 🍽️ Nombre: Macarrones con Chorizo
# Ingredientes: Tomate, Sémola de trigo 22.90% (GLUTEN), Chorizo 14.75%, Cebolla, Pimiento, Aceite de Oliva, Sal y Orégano
# Kcal: 195.0
# Diferencias detectadas:
#  • is_vegano: heurístico=True, agente=False
#  • is_vegetariano: heurístico=True, agente=False
#  • congelar: heurístico=True, agente=False
# --------------------------------------------------
#
# --------------------------------------------------
# 🍽️ Nombre: Pollo a la Manzanilla con Bechamel y Espirales
# Ingredientes: Pollo 49.57%, Sémola de trigo 16,44% (GLUTEN), leche Sin Lactosa (LÁCTEOS), Agua, Sal, Aceite de Oliva, Nuez Moscada, Harina de maiz, Setas, Vino, Salsa de soja (SOJA) y Azúcar
# Kcal: 181.0
# Diferencias detectadas:
#  • es_postre: heurístico=True, agente=False
# --------------------------------------------------
#
# --------------------------------------------------
# 🍽️ Nombre: Tallarines a la Puttanesca
# Ingredientes: Tomate, Sémola de trigo 25.65%, Tomates, Anchoas (PESCADO), Aceitunas negras, Alcaparras, Aceite de Oliva, Ajo, Tabasco, Sal y Orégano
# Kcal: 169.0
# Diferencias detectadas:
#  • congelar: heurístico=True, agente=False
# --------------------------------------------------
#
# --------------------------------------------------
# 🍽️ Nombre: Tortellini de Queso con Salsa de Jamón
# Ingredientes: Nata (LÁCTEOS), leche Sin Lactosa (LÁCTEOS), Sémola de trigo 24%(GLUTEN), Leche  (LÁCTEOS), Jamón 7.06%, Margarina, Sal, Pimienta Blanca, Roast Pork y Nuez Moscada
# Kcal: 119.0
# Diferencias detectadas:
#  • es_postre: heurístico=True, agente=False
# --------------------------------------------------
#
# --------------------------------------------------
# 🍽️ Nombre: Tortellini de Setas con Salsa a los 3 Quesos
# Ingredientes: leche  Sin Lactosa(LÁCTEOS), Sémola de trigo 31.74% (GLUTEN), Nata (LÁCTEOS), Queso Roquefort 3.77% (LÁCTEOS), Queso 3.73% (LÁCTEOS), Queso Sin Lactosa 3.68% (LÁCTEOS), Aceite de Oliva, Ajo y Sal
# Kcal: 143.0
# Diferencias detectadas:
#  • es_postre: heurístico=True, agente=False
# --------------------------------------------------
#
# --------------------------------------------------
# 🍽️ Nombre: Wok de Ternera y Verduritas
# Ingredientes: Ternera 47.56%, Salsa de Ostras (Agua, Azúcar, Extracto de Ostras (MOLUSCOS), Agua y Sal), Cebolla, Sémola de trigo 7.13% (GLUTEN), Pimiento, Zanahoria, Aceite de Oliva, Salsa de Soja (SOJA), Sal, Azúcar, Ajo, Sal, Roast Pork y Pimienta Negra
# Kcal: 134.0
# Diferencias detectadas:
#  • is_vegano: heurístico=True, agente=False
#  • is_vegetariano: heurístico=True, agente=False
#  • es_postre: heurístico=True, agente=False
#  • congelar: heurístico=True, agente=False
# --------------------------------------------------
#
# --------------------------------------------------
# 🍽️ Nombre: Yakisoba con Gambas
# ...
# Kcal: 78.1
# Diferencias detectadas:
#  • sin_gluten: heurístico=True, agente=False
# --------------------------------------------------
#
# --------------------------------------------------
# 🍽️ Nombre: Albóndigas en Salsa de la Abuela +GRANDE
# Ingredientes: Ternera 10.93%, Cerdo 10.93%, Perejil, Cebolla, Huevo (HUEVO), Ajo, Caldo de Carne, Pan (GLUTEN) y leche Sin Lactosa (LÁCTEOS)), Vino, Aceite de Oliva, Pimienta, Pimentón, Pollo, Roast Pork, Tomate, Zanahoria y Guisantes
# Kcal: 129.0
# Diferencias detectadas:
#  • sin_gluten: heurístico=True, agente=False
# --------------------------------------------------
#
# --------------------------------------------------
# 🍽️ Nombre: Bacalao al Pilpil con Pimientos del Piquillo +GRANDE
# Ingredientes: Bacalao 71.34% (PESCADO) , Aceite de Oliva 14.24%, Pimientos del Piquillo, Ajo y Goma Xantana
# Kcal: 0.0
# Diferencias detectadas:
#  • is_keto: heurístico=False, agente=True
# --------------------------------------------------
#
# --------------------------------------------------
# 🍽️ Nombre: Calabacines Rellenos de Carne +GRANDE
# Ingredientes: Calabacines 45.70%, Queso sin Lactosa (LÁCTEOS), leche  Sin Lactosa(LÁCTEOS), Agua, Cerdo 6.58%, Cebolla, Tomate, Aceite de Oliva, Harina de maiz, Vino, Patatas, Pimiento, Zanahoria, Sal, Ajo, Nuez Moscada y Pimienta
# Kcal: 96.0
# Diferencias detectadas:
#  • bajo_en_calorias: heurístico=False, agente=True
#  • sin_lactosa: heurístico=False, agente=True
#  • sin_gluten: heurístico=False, agente=True
# --------------------------------------------------
#
# --------------------------------------------------
# 🍽️ Nombre: Carrilleras de Cerdo en Salsa con Crema de Patatas +GRANDE
# Ingredientes: Cerdo 60.82%, Agua, Patatas 8.12%, Cebolla, Zanahoria, Pimiento, Vino, Nata (LÁCTEOS), Aceite de Oliva, Ajo, Vino, Sal, Mantequilla (LÁCTEOS), Caldo de Carne, Pimienta Negra y Nuez Moscada.
# Kcal: 172.0
# Diferencias detectadas:
#  • es_postre: heurístico=True, agente=False
# --------------------------------------------------
#
# --------------------------------------------------
# 🍽️ Nombre: Cazuela de Fideos con Marisco y Pescado +GRANDE
# Ingredientes: Agua, Gambas 51.26% (CRUSTÁCEOS), Patatas, Fideos 5.69% (GLUTEN), Calamares 5.47% (PESCADO), Rosada 3.87% (PESCADO), Mejillón 3.03% (MOLUSCOS), Cebolla, Aceite de Oliva,Almeja 1.14%, Guisantes, Vino, Caldo de Pescado (PESCADO), Pimiento, Pimiento, Sal, Ajo, Pimentón Dulce y Pimienta Blanca.
# Kcal: 51.0
# Diferencias detectadas:
#  • es_postre: heurístico=True, agente=False
#  • de_cuchara: heurístico=False, agente=True
#  • sin_gluten: heurístico=True, agente=False
# --------------------------------------------------
#
# --------------------------------------------------
# 🍽️ Nombre: Cocido Madrileño +GRANDE
# Ingredientes: Agua, Garbanzos 30.62%, Patatas, Cerdo, Pollo, Col, Zanahoria, Cebolla, Chorizo, Morcilla, Aceite de Oliva, Caldo de Carne, Sal y Hueso de Jamón
# Kcal: 101.0
# Diferencias detectadas:
#  • de_cuchara: heurístico=False, agente=True
# --------------------------------------------------
#
# --------------------------------------------------
# 🍽️ Nombre: Fabada Asturiana Casera +GRANDE
# Ingredientes: Agua, Fabes 12.84%, Cerdo, Lacon, Chorizo Asturiano, Morcilla Asturiana, Aceite de Oliva y Pimentón Dulce
# Kcal: 156.0
# Diferencias detectadas:
#  • es_postre: heurístico=True, agente=False
#  • de_cuchara: heurístico=False, agente=True
# --------------------------------------------------
#
# --------------------------------------------------
# 🍽️ Nombre: Garbanzos con Langostinos y Chorizo +GRANDE
# Ingredientes: Garbanzos 42.18%, Langostino (CRUSTÁCEOS) 20.46%, Agua, Chorizo 5.30%, Cebolla, Pimiento, Tomate, Vino, Aceite de Oliva, Sal, Harina de maiz, Caldo de Carne, Ajo y Perejil
# Kcal: 152.0
# Diferencias detectadas:
#  • de_cuchara: heurístico=False, agente=True
#  • congelar: heurístico=True, agente=False
# --------------------------------------------------
#
# --------------------------------------------------
# 🍽️ Nombre: Garbanzos con Verduras +GRANDES
# Ingredientes: Garbanzos 20.50, Pimiento 13.45%, Cebolla, 11.53%, Zanahoria 9.81%, Agua, Tomate 9.06%, Calabaza 7.69%, Judías Verdes 6.41%, Calabacín 5.68%, Patata 2.56%, Aceite de Oliva, Ajo, Caldo de Verduras y Pimentón Dulce
# Kcal: 73.7
# Diferencias detectadas:
#  • es_postre: heurístico=True, agente=False
#  • de_cuchara: heurístico=False, agente=True
# --------------------------------------------------
#
# --------------------------------------------------
# 🍽️ Nombre: Judías Blancas con Chorizo +GRANDES
# Ingredientes: Alubias Blancas 36.26%, Agua, Patata, Cebolla, Chorizo 7.93%, Pimiento, Zanahoria, Aceite de Oliva, Ajo, Sal y Pimentón Dulce
# Kcal: 91.1
# Diferencias detectadas:
#  • is_vegano: heurístico=True, agente=False
#  • is_vegetariano: heurístico=True, agente=False
#  • bajo_en_calorias: heurístico=False, agente=True
#  • es_postre: heurístico=True, agente=False
#  • de_cuchara: heurístico=False, agente=True
# --------------------------------------------------
#
# --------------------------------------------------
# 🍽️ Nombre: Judías Pintas con Verduritas y Jamón Serrano +GRANDE
# Ingredientes: Judías Pintas 39.96%, Agua, Jamón 12.65%, Zanahoria 5.20%, Cebolla 5.05%, Tomates 3.29, Pimiento 5,5%, Aceite de Oliva, Ajo, Pimentón dulce, Sal, Pimienta Blanca y Laurel
# Kcal: 99.6
# Diferencias detectadas:
#  • bajo_en_calorias: heurístico=False, agente=True
#  • es_postre: heurístico=True, agente=False
#  • de_cuchara: heurístico=False, agente=True
# --------------------------------------------------
#
# --------------------------------------------------
# 🍽️ Nombre: Lentejas con Verduras +GRANDES
# Ingredientes: Agua, Lentejas 13.61%, Patata 10.20%, Zanahoria 7.99%, Cebolla 6.80%, Calabaza 5.44%, Tomate 4.08%, Pimiento 6.80%, Puerro 2.72%, Aceite de Oliva, Caldo de Verduras, Ajo y Pimentón Dulce
# Kcal: 73.7
# Diferencias detectadas:
#  • es_postre: heurístico=True, agente=False
#  • de_cuchara: heurístico=False, agente=True
# --------------------------------------------------
#
# --------------------------------------------------
# 🍽️ Nombre: Lentejas Riojanas +GRANDES
# Ingredientes: Agua, Lentejas 18.25%, Patata, Chorizo 10.48%, Zanahoria, Cebolla, Pimiento, Aceite de Oliva, Sal, Pimentón Dulce y Laurel
# Kcal: 94.4
# Diferencias detectadas:
#  • is_vegano: heurístico=True, agente=False
#  • is_vegetariano: heurístico=True, agente=False
#  • bajo_en_calorias: heurístico=False, agente=True
#  • es_postre: heurístico=True, agente=False
#  • de_cuchara: heurístico=False, agente=True
#  • sin_gluten: heurístico=True, agente=False
# --------------------------------------------------
#
# --------------------------------------------------
# 🍽️ Nombre: Marmitako de Atún +GRANDE
# Ingredientes: Patatas, Agua, Atún 18.40% (PESCADO), Cebolla, Vino, Pimiento, Aceite de Oliva, caldo de Pescado, Sal, Ajo, Colorante, Pimienta Blanca y Laurel
# Kcal: 66.9
# Diferencias detectadas:
#  • de_cuchara: heurístico=False, agente=True
# --------------------------------------------------
#
# --------------------------------------------------
# 🍽️ Nombre: Musaka +GRANDE
# Ingredientes: Berenjenas 57.36%, leche (LÁCTEOS) Sin Lactosa, Agua, Ternera, Cerdo, Tomate, Queso Sin Lactosa (LÁCTEOS), Cebolla, Aceite de Oliva, Harina de maiz, Zanahoria, Bacon, Vino, Sal, Ajo, Caldo de Carne, Nuez Moscada y Orégano
# Kcal: 103.0
# Diferencias detectadas:
#  • sin_lactosa: heurístico=False, agente=True
#  • sin_gluten: heurístico=False, agente=True
# --------------------------------------------------
#
# --------------------------------------------------
# 🍽️ Nombre: Pavo al Curry y Coliflor +GRANDE
# Ingredientes: Pavo 41.72%, Coliflor 32.10%, Queso (LÁCTEOS), Cebolla, Nata (LÁCTEOS), Tomate, Aceite de Oliva, Curry Amarillo 0.39% y Sal
# Kcal: 90.6
# Diferencias detectadas:
#  • is_vegetariano: heurístico=True, agente=False
#  • is_keto: heurístico=False, agente=True
#  • bajo_en_calorias: heurístico=False, agente=True
#  • es_postre: heurístico=True, agente=False
#  • alto_proteina: heurístico=False, agente=True
# --------------------------------------------------
#
# --------------------------------------------------
# 🍽️ Nombre: Pollo a la Carbonara con Champiñones +GRANDE
# Ingredientes: Pollo 50.80%, Champiñones 19.94%, Nata (LÁCTEOS), Cebolla, Queso (LÁCTEOS), Mantequilla (LÁCTEOS), Aceite de Oliva, Ajo, Sal y Pimienta
# Kcal: 98.0
# Diferencias detectadas:
#  • is_keto: heurístico=False, agente=True
#  • bajo_en_calorias: heurístico=False, agente=True
#  • es_postre: heurístico=True, agente=False
# --------------------------------------------------
#
# --------------------------------------------------
# 🍽️ Nombre: Pollo al Curry con Arroz +GRANDE
# Ingredientes: Pollo 33.14%, Agua, Nara, Arroz 8.93%, Manzana, leche (LÁCTEOS), Cebolla, Tomate, Aceite de Oliva, Limón, Curry Amarillo 0.71%, Caldo de Carne, Mantequilla (LÁCTEOS), Ajo, Sal, Cayena, Comino, Canela, Colorante y Pimienta Negra
# Kcal: 127.0
# Diferencias detectadas:
#  • es_postre: heurístico=True, agente=False
# --------------------------------------------------
#
# --------------------------------------------------
# 🍽️ Nombre: Pollo Asado a la Peruana +GRANDE
# Ingredientes: Pollo 49.76%, Patata, Agua, Carne de Pimiento Choricero, Nata (LÁCTEOS), Vino, Mostaza (MOSTAZA), Limón, Aceite de Oliva, Harina de maiz, Ají Amarillo, Sal, Comino, Ajo, Tomillo, Pimienta Negra y Orégano
# Kcal: 88.8
# Diferencias detectadas:
#  • bajo_en_calorias: heurístico=False, agente=True
#  • es_postre: heurístico=True, agente=False
#  • sin_gluten: heurístico=False, agente=True
# --------------------------------------------------
#
# --------------------------------------------------
# 🍽️ Nombre: Pollo Tikka Masala con Arroz Basmati + GRANDE
# Ingredientes: Pollo 37.58%, Agua, Tomate, Arroz 9.40%, Cebolla, Nata (LÁCTEOS), Tomate, Mantequilla (LÁCTEOS), Ajo, Aceite de Oliva, Comino, Sal, Canela, Curry, Jengibre, Azúcar, Cúrcuma, Cayena, Ajo y Pimentón dulce
# Kcal: 220.0
# Diferencias detectadas:
#  • es_postre: heurístico=True, agente=False
# --------------------------------------------------
#
# --------------------------------------------------
# 🍽️ Nombre: Solomillo a la Pimienta + GRANDE
# Ingredientes: Patata 41.44%, Cerdo 39.74%, Nata (LÁCTEOS), Cebolla, Vino, Aceite de Oliva, Ajo, bovril (Caldo de Vacuno, Extracto de Levadura, Sal, Agua, Colorante, Almidón de Maíz, Carne de Vacuno Desidratada, Potenciadores del Sabor, Acidulante y Aromas), Sal, Pimienta en Grano y Pimienta Molida
# Kcal: 120.0
# Diferencias detectadas:
#  • es_postre: heurístico=True, agente=False
# --------------------------------------------------
#
# --------------------------------------------------
# 🍽️ Nombre: Wok de Ternera y Verduritas +GRANDE
# Ingredientes: Ternera 47.56%, Salsa de Ostras (Agua, Azúcar, Extracto de Ostras (MOLUSCOS), Agua y Sal), Cebolla, Sémola de trigo 7.13% (GLUTEN), Pimiento, Zanahoria, Aceite de Oliva, Salsa de Soja (SOJA), Sal, Azúcar, Ajo, Sal, Roast Pork y Pimienta Negra
# Kcal: 134.0
# Diferencias detectadas:
#  • is_vegano: heurístico=True, agente=False
#  • is_vegetariano: heurístico=True, agente=False
#  • es_postre: heurístico=True, agente=False
#  • alto_proteina: heurístico=False, agente=True
#  • congelar: heurístico=True, agente=False
# --------------------------------------------------
#
# --------------------------------------------------
# 🍽️ Nombre: Lentejas Riojanas FAMILIAR
# Ingredientes: Agua, Lentejas 18.25%, Patata, Chorizo 10.48%, Zanahoria, Cebolla, Pimiento, Aceite de Oliva, Sal, Pimentón Dulce y Laurel
# Kcal: 94.4
# Diferencias detectadas:
#  • is_vegano: heurístico=True, agente=False
#  • is_vegetariano: heurístico=True, agente=False
#  • bajo_en_calorias: heurístico=False, agente=True
#  • es_postre: heurístico=True, agente=False
#  • de_cuchara: heurístico=False, agente=True
#  • sin_gluten: heurístico=True, agente=False
# --------------------------------------------------
#
# --------------------------------------------------
# 🍽️ Nombre: Carrilleras de Cerdo en Salsa con Crema de Patatas FAMILIAR
# Ingredientes: Cerdo 60.82%, Agua, Patatas 8.12%, Cebolla, Zanahoria, Pimiento, Vino, Nata (LÁCTEOS), Aceite de Oliva, Ajo, Vino, Sal, Mantequilla (LÁCTEOS), Caldo de Carne, Pimienta Negra y Nuez Moscada.
# Kcal: 172.0
# Diferencias detectadas:
#  • es_postre: heurístico=True, agente=False
# --------------------------------------------------
#
# --------------------------------------------------
# 🍽️ Nombre: Lentejas con Verduras FAMILIAR
# Ingredientes: Agua, Lentejas 13.61%, Patata 10.20%, Zanahoria 7.99%, Cebolla 6.80%, Calabaza 5.44%, Tomate 4.08%, Pimiento 6.80%, Puerro 2.72%, Aceite de Oliva, Caldo de Verduras, Ajo y Pimentón Dulce
# Kcal: 73.7
# Diferencias detectadas:
#  • es_postre: heurístico=True, agente=False
#  • de_cuchara: heurístico=False, agente=True
# --------------------------------------------------
#
# --------------------------------------------------
# 🍽️ Nombre: Arroz Tikka Masala con Heura
# Ingredientes: Agua, concentrado de Proteína de Soja (SOJA), Aceite de Oliva, Sal, Aromas, Especias, Vitamina B12, Agua, Arroz 12.42, Tomate, Cebolla, leche de Coco, Aceite de Oliva, Ajo, Comino, Sal, Canela, Curry Amarillo, Jengibre, Cúrcuma, Pimentón Picante y Pimentón Dulce
# Kcal: 188.0
# Diferencias detectadas:
#  • is_vegano: heurístico=False, agente=True
#  • es_postre: heurístico=True, agente=False
#  • sin_lactosa: heurístico=False, agente=True
#  • congelar: heurístico=False, agente=True
# --------------------------------------------------
#
# --------------------------------------------------
# 🍽️ Nombre: Cuscús de Verduras y Pollo
# Ingredientes: Agua, Sémola de trigo 25.41% (GLUTEN), Pollo 19.06%, Calabacín 5.72%, Zanahoria 5.08%, Aceite de Oliva, Pimiento 2.54%, Pimiento 2.54%, Almendra (FRUTOS DE CÁSCARA), Caldo de Verduras, Comino, Curry Amarillo 0.29%, Sal y Pimienta Negra
# Kcal: 174.0
# Diferencias detectadas:
#  • congelar: heurístico=True, agente=False
# --------------------------------------------------
#
# ✅ df_final_official is ready:
#                              nombre_plato  \
# 0                            Ají de Pollo
# 1                           Arroz Campero
# 2  Arroz con Carrilleras al Pedro Ximénez
# 3                         Arroz con Pollo
# 4       Arroz Meloso al Parmesano y Setas
#
#                                         ingredientes  precio   kcal  \
# 0  Pollo, 26.38%, Agua, Cebolla, Huevo (HUEVO), l...    6.95  146.0
# 1  Agua, Pollo, Pimientos, Arroz 13.23%, Chorizo,...    6.45  138.0
# 2  Agua, Cerdo 22.67%, Arroz 13.60%, Vino, Ceboll...    6.45  198.0
# 3  Pollo 29.33%, Agua, Arroz 19.69%, Cebolla, Vin...    6.45  154.0
# 4  Agua, Arroz, Setas, Leche  Sin Lactosa(LÁCTEOS...    5.55  146.0
#
#    proteinas  hidratos  grasas   peso  \
# 0        8.9      13.6     6.0  380.0
# 1        6.2      13.3     6.5  430.0
# 2       10.0      14.1    11.1  430.0
# 3        6.0      19.2     5.7  430.0
# 4        3.4      17.0     6.5  430.0
#
#                                    alergenos  is_vegetariano  ...  is_keto  \
# 0  HUEVO, LÁCTEOS, GLUTEN, FRUTOS DE CÁSCARA           False  ...    False
# 1                                       None           False  ...    False
# 2                                       None           False  ...    False
# 3                                       None           False  ...    False
# 4                                    LÁCTEOS            True  ...    False
#
#    bajo_en_calorias  es_postre  de_cuchara  alto_proteina  sin_lactosa  \
# 0             False      False       False          False        False
# 1             False      False       False          False         True
# 2             False      False       False          False         True
# 3             False      False       False          False         True
# 4             False      False        True          False         True
#
#    is_gourmet  para_diabeticos  sin_gluten  congelar
# 0        True            False       False     False
# 1       False            False       False     False
# 2        True            False        True     False
# 3       False            False        True     False
# 4        True            False        True     False
#
# [5 rows x 21 columns]

# %%
# Saving
df_final_official = df_final_official[~df_final_official['nombre_plato'].str.contains("pack", case=False, na=False)]
df_final_official.to_csv("data/df_final_official.csv", index=False)
print("✅ Saved df_final_official.csv")
# Out:
# ✅ Saved df_final_official.csv

# %%
df_final_official
# Out:
#                                           nombre_plato  \
# 0                                         Ají de Pollo
# 1                                        Arroz Campero
# 2               Arroz con Carrilleras al Pedro Ximénez
# 3                                      Arroz con Pollo
# 4                    Arroz Meloso al Parmesano y Setas
# ..                                                 ...
# 236                         Lentejas Riojanas FAMILIAR
# 237  Carrilleras de Cerdo en Salsa con Crema de Pat...
# 238                     Lentejas con Verduras FAMILIAR
# 239                       Arroz Tikka Masala con Heura
# 240                         Cuscús de Verduras y Pollo
#
#                                           ingredientes  precio   kcal  \
# 0    Pollo, 26.38%, Agua, Cebolla, Huevo (HUEVO), l...    6.95  146.0
# 1    Agua, Pollo, Pimientos, Arroz 13.23%, Chorizo,...    6.45  138.0
# 2    Agua, Cerdo 22.67%, Arroz 13.60%, Vino, Ceboll...    6.45  198.0
# 3    Pollo 29.33%, Agua, Arroz 19.69%, Cebolla, Vin...    6.45  154.0
# 4    Agua, Arroz, Setas, Leche  Sin Lactosa(LÁCTEOS...    5.55  146.0
# ..                                                 ...     ...    ...
# 236  Agua, Lentejas 18.25%, Patata, Chorizo 10.48%,...   15.55   94.4
# 237  Cerdo 60.82%, Agua, Patatas 8.12%, Cebolla, Za...   20.05  172.0
# 238  Agua, Lentejas 13.61%, Patata 10.20%, Zanahori...   15.55   73.7
# 239  Agua, concentrado de Proteína de Soja (SOJA), ...    5.45  188.0
# 240  Agua, Sémola de trigo 25.41% (GLUTEN), Pollo 1...    5.85  174.0
#
#      proteinas  hidratos  grasas    peso  \
# 0          8.9      13.6     6.0   380.0
# 1          6.2      13.3     6.5   430.0
# 2         10.0      14.1    11.1   430.0
# 3          6.0      19.2     5.7   430.0
# 4          3.4      17.0     6.5   430.0
# ..         ...       ...     ...     ...
# 236        6.3       9.3     2.8  1100.0
# 237       13.5      14.5     5.9  1100.0
# 238        4.0       8.2     2.0  1100.0
# 239        8.9      17.7     8.9   380.0
# 240        8.0      20.3     6.2   340.0
#
#                                      alergenos  is_vegetariano  ...  is_keto  \
# 0    HUEVO, LÁCTEOS, GLUTEN, FRUTOS DE CÁSCARA           False  ...    False
# 1                                         None           False  ...    False
# 2                                         None           False  ...    False
# 3                                         None           False  ...    False
# 4                                      LÁCTEOS            True  ...    False
# ..                                         ...             ...  ...      ...
# 236                                       None           False  ...    False
# 237                                    LÁCTEOS           False  ...    False
# 238                                       None            True  ...    False
# 239                                       SOJA            True  ...    False
# 240                  GLUTEN, FRUTOS DE CÁSCARA           False  ...    False
#
#      bajo_en_calorias  es_postre  de_cuchara  alto_proteina  sin_lactosa  \
# 0               False      False       False          False        False
# 1               False      False       False          False         True
# 2               False      False       False          False         True
# 3               False      False       False          False         True
# 4               False      False        True          False         True
# ..                ...        ...         ...            ...          ...
# 236              True      False        True          False         True
# 237             False      False        True           True        False
# 238              True      False        True          False         True
# 239             False      False       False          False         True
# 240             False      False       False          False         True
#
#      is_gourmet  para_diabeticos  sin_gluten  congelar
# 0          True            False       False     False
# 1         False            False       False     False
# 2          True            False        True     False
# 3         False            False        True     False
# 4          True            False        True     False
# ..          ...              ...         ...       ...
# 236       False             True       False     False
# 237        True            False        True     False
# 238       False             True        True     False
# 239        True             True        True      True
# 240       False             True       False     False
#
# [215 rows x 21 columns]
